# %%
import matplotlib.pyplot as plt

# clip
model_path = '/home/sangyeob/dev/d2d/5-K_stable_diffusion/train_result/clip'
train_loss = [0.7976, 0.6741, 0.5949, 0.5360, 0.5000]
valid_loss = [0.7227, 0.6502, 0.6017, 0.5723, 0.5647]
valid_loss_en = [0.1214, 0.1110, 0.0897, 0.0737, 0.0694]
valid_loss_ko = [0.6013, 0.5392, 0.5120, 0.4986, 0.4954]

# # roberta
# model_path = '/home/sangyeob/dev/d2d/5-K_stable_diffusion/train_result/roberta'
# train_loss = [1.3523, 1.1160, 1.0371, 0.9965, 0.9792]
# valid_loss = [1.1503, 1.0387, 0.9899, 0.9689, 0.9631]
# valid_loss_en = [0.5709, 0.5089, 0.4802, 0.4679, 0.4643]
# valid_loss_ko = [0.5794, 0.5298, 0.5097, 0.5010, 0.4988]

# roberta-pooler
# model_path = '/home/sangyeob/dev/d2d/5-K_stable_diffusion/train_result/roberta_pooler'
# train_loss = [1.3590, 1.1826, 1.1235, 1.0910, 1.0766]
# valid_loss = [1.2077, 1.1360, 1.1013, 1.0849, 1.0813]
# valid_loss_en = [0.6051, 0.5642, 0.5438, 0.5339, 0.5319]
# valid_loss_ko = [0.6026, 0.5717, 0.5576, 0.5509, 0.5494]

plt.rc('font', family='NanumGothic', size = 7.5)

plt.title('Training/Valid loss history')
plt.plot(train_loss, label='train_loss')
plt.plot(valid_loss, label='valid_loss')
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig(model_path + '/result.jpg')

plt.cla()

plt.title('Valid En/Ko loss history')
plt.plot(valid_loss_en, label='loss_en')
plt.plot(valid_loss_ko, label='loss_ko')
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig(model_path + '/enko_result.jpg')
